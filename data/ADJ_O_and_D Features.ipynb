# %%
import pandas as pd
import numpy as np
from html.parser import HTMLParser
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import requests
import json
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
def get_data(year):
    url = 'https://kenpom.com/index.php?y='+str(year)+'&s=TeamName'
    r  = requests.get(url)
    data = r.text
    soup = BeautifulSoup(data)

    table = soup.find_all('table')[0] 

    return pd.read_html(str(table))[0]

# %% [markdown]
# - Insert the year you want for data on AdjO, AdjD, and Luck below

# %%
d1 = get_data(2012)
d1
# Out:
#     Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk                  Team               Conf
# 0                  188             Air Force                MWC
# 1                   70               Akron 5                MAC
# 2                   27             Alabama 9                SEC
# 3                  337           Alabama A&M               SWAC
# 4                  315           Alabama St.               SWAC
# 5                  199                Albany                 AE
# 6                  331            Alcorn St.               SWAC
# 7                  177              American                Pat
# 8                  258       Appalachian St.                 SC
# 9                   51             Arizona 1                P12
# 10                 230           Arizona St.                P12
# 11                 127              Arkansas                SEC
# 12                 180  Arkansas Little Rock                 SB
# ...

# %%
d1.to_csv('./bballdata.csv')

# %%
df = pd.read_csv('./bballdata.csv')
df
# Out:
#      Unnamed: 0 Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0           NaN                 Rk                  Team               Conf
# 1           0.0                188             Air Force                MWC
# 2           1.0                 70               Akron 5                MAC
# 3           2.0                 27             Alabama 9                SEC
# 4           3.0                337           Alabama A&M               SWAC
# 5           4.0                315           Alabama St.               SWAC
# 6           5.0                199                Albany                 AE
# 7           6.0                331            Alcorn St.               SWAC
# 8           7.0                177              American                Pat
# 9           8.0                258       Appalachian St.                 SC
# 10          9.0                 51             Arizona 1                P12
# ...

# %%
ADJ_O_and_D = df[['Unnamed: 0_level_0','Unnamed: 1_level_0','Unnamed: 5_level_0','Strength of Schedule','Unnamed: 8_level_0']]
ADJ_O_and_D.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 5_level_0  \
# 0                 Rk               Team               AdjO
# 1                188          Air Force              100.0
# 2                 70            Akron 5              108.3
# 3                 27          Alabama 9              106.1
# 4                337        Alabama A&M               90.0
#
#   Strength of Schedule Unnamed: 8_level_0
# 0                 AdjD               Luck
# 1                  229                155
# 2                   81                 74
# 3                  115                  6
# 4                  329                318

# %%
df_final = pd.DataFrame(ADJ_O_and_D)

# %%
df_final.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 5_level_0  \
# 0                 Rk               Team               AdjO
# 1                188          Air Force              100.0
# 2                 70            Akron 5              108.3
# 3                 27          Alabama 9              106.1
# 4                337        Alabama A&M               90.0
#
#   Strength of Schedule Unnamed: 8_level_0
# 0                 AdjD               Luck
# 1                  229                155
# 2                   81                 74
# 3                  115                  6
# 4                  329                318

# %%
ADJ_O_and_D.columns = ['Rank', 'Team','AdjO', 'AdjD','Luck']
ADJ_O_and_D.head()
# Out:
#   Rank         Team   AdjO  AdjD  Luck
# 0   Rk         Team   AdjO  AdjD  Luck
# 1  188    Air Force  100.0   229   155
# 2   70      Akron 5  108.3    81    74
# 3   27    Alabama 9  106.1   115     6
# 4  337  Alabama A&M   90.0   329   318

# %%
ADJ_O_and_D = ADJ_O_and_D.iloc[1:]

# %%
ADJ_O_and_D.head()
# Out:
#   Rank         Team   AdjO AdjD Luck
# 1  188    Air Force  100.0  229  155
# 2   70      Akron 5  108.3   81   74
# 3   27    Alabama 9  106.1  115    6
# 4  337  Alabama A&M   90.0  329  318
# 5  315  Alabama St.   87.8  338  213
